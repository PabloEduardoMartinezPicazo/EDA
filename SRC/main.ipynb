# %%
import pandas as pd
import numpy as np
import sys,os
import seaborn as sns
import matplotlib.pyplot as plt
path = os.path.dirname(os.getcwd())
sys.path.append(path)
from notebooks.Canada import df_canada
from notebooks.Canada_2 import df_canada1
from notebooks.Japon import df_japon
from notebooks.Japon_2 import df_japon1
from notebooks.Vietnam import df_vietnam
from notebooks.Singapur import df_singapur
from notebooks.Corea import df_corea
from notebooks.Corea_aranceles import df_corea1
from notebooks.paisesfinal import df_paises
from notebooks.Aranceles import aranceles
from SRC.utils_.mining_data_tb import *
from SRC.utils_.visualization_tb import *
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
# Out:
#        País Tarics             Descripción   Año Exportaciones Importaciones
# 0    Canadá   0201      Productos cárnicos  2006           nan       5947.37
# 1    Canadá   0202      Productos cárnicos  2006         34.98        514.35
# 2    Canadá   0203      Productos cárnicos  2006      14345.47      77131.81
# 3    Canadá   0204      Productos cárnicos  2006           nan           nan
# 4    Canadá   0205      Productos cárnicos  2006           nan      13584.16
# ..      ...    ...                     ...   ...           ...           ...
# 850  Canadá   2207                 Bebidas  2020       1503.85      44408.23
# 851  Canadá   1803              Chocolates  2020      13351.44         47.74
# 852  Canadá   1804              Chocolates  2020       4443.20      37409.36
# 853  Canadá   1805              Chocolates  2020      10068.71        154.90
# 854  Canadá   1905  Panaderia y pastelería  2020     150387.33       4762.42
#
# [855 rows x 6 columns]
# ...

# %% [markdown]
# Dataframe madre

# %%
df_paises.head()
# Out:
#      País   Año  Exportaciones  Importaciones
# 0  Canadá  2006     1051286.27      210136.81
# 1  Canadá  2007     1088818.35      140204.41
# 2  Canadá  2008     1141357.97      150042.40
# 3  Canadá  2009     1023324.94      117085.06
# 4  Canadá  2010     1245802.17      106363.21

# %% [markdown]
# Exportaciones e importaciones totales

# %%
totalitos(df_paises).show
# Out:
# <bound method Figure.show of <Figure size 2160x720 with 2 Axes>>

# %% [markdown]
# Exportaciones totales

# %%
exportaciones_totalitos (df_paises).show
# Out:
# <bound method Figure.show of <Figure size 2160x720 with 1 Axes>>

# %% [markdown]
# Importaciones totales

# %%
importaciones_totalitos (df_paises).show
# Out:
# <bound method Figure.show of <Figure size 2160x720 with 1 Axes>>

# %% [markdown]
# Paises totales por tarics y paises totales antes y despues del acuerdo

# %%
df_canada.head()
# Out:
#      País Tarics         Descripción   Año Exportaciones Importaciones
# 0  Canadá   0201  Productos cárnicos  2006           nan       5947.37
# 1  Canadá   0202  Productos cárnicos  2006         34.98        514.35
# 2  Canadá   0203  Productos cárnicos  2006      14345.47      77131.81
# 3  Canadá   0204  Productos cárnicos  2006           nan           nan
# 4  Canadá   0205  Productos cárnicos  2006           nan      13584.16

# %%
df_canada1.head()
# Out:
#           Descripción   Año  Exportaciones  Importaciones
# 0             Aceites  2014      102057.01          24.51
# 1             Aceites  2020      125189.44          96.12
# 2             Bebidas  2014      978623.81        4577.59
# 3             Bebidas  2020     1246617.94       52023.81
# 4  Cereales y harinas  2014        2516.26         980.54

# %%
exportaciones_total (df_canada1,"Canadá")

# %%
importaciones_total (df_canada1,"Canadá")

# %% [markdown]
# Paises totales por tarics y paises totales antes y despues del acuerdo

# %%
df_corea.head()
# Out:
#             País Tarics         Descripción   Año Exportaciones Importaciones
# 0  Corea del Sur   0201  Productos cárnicos  2006          0.25           nan
# 1  Corea del Sur   0202  Productos cárnicos  2006         38.01           nan
# 2  Corea del Sur   0203  Productos cárnicos  2006     309273.64        609.00
# 3  Corea del Sur   0204  Productos cárnicos  2006           nan           nan
# 4  Corea del Sur   0205  Productos cárnicos  2006           nan           nan

# %%
df_corea1.head()
# Out:
#           Descripción   Año  Exportaciones  Importaciones  \
# 0             Aceites  2011      121154.79           9.25
# 1             Aceites  2020      191840.75          77.43
# 2             Bebidas  2011     1003033.55       17089.11
# 3             Bebidas  2020     1585370.69       38412.81
# 4  Cereales y harinas  2011        3048.44         130.50
#
#    Aranceles Corea - UE  Aranceles UE - Corea  Cambio Exportaciones (%)  \
# 0                  10.0                   8.0                         0
# 1                   0.0                   0.0                        58
# 2                  20.0                  13.5                         0
# 3                   3.0                   0.0                        58
# 4                 335.0                 150.0                         0
#
#    Cambio Importaciones (%)
# 0                         0
# 1                       738
# 2                         0
# 3                       125
# 4                         0

# %%
exportaciones_total (df_corea1,"Corea del Sur")

# %%
importaciones_total (df_corea1,"Corea del Sur")

# %% [markdown]
# Paises totales por tarics y paises totales antes y despues del acuerdo

# %%
df_japon.head()
# Out:
#     País Tarics         Descripción   Año Exportaciones Importaciones
# 0  Japón   0201  Productos cárnicos  2006         23.42           nan
# 1  Japón   0202  Productos cárnicos  2006          0.07           nan
# 2  Japón   0203  Productos cárnicos  2006     717675.83        145.87
# 3  Japón   0204  Productos cárnicos  2006           nan           nan
# 4  Japón   0205  Productos cárnicos  2006        847.07           nan

# %%
df_japon1.head()
# Out:
#           Descripción   Año  Exportaciones  Importaciones
# 0             Aceites  2018      242365.47         376.44
# 1             Aceites  2020      228242.17         233.28
# 2             Bebidas  2018      964654.65       15947.09
# 3             Bebidas  2020      939878.95       19905.63
# 4  Cereales y harinas  2018        4917.14         901.82

# %%
exportaciones_total (df_japon1,"Japón")

# %%
importaciones_total (df_japon1,"Japón")

# %% [markdown]
# Paises totales por tarics

# %%
df_singapur.head()
# Out:
#        País Tarics         Descripción   Año Exportaciones Importaciones
# 0  Singapur   0201  Productos cárnicos  2006          0.95           nan
# 1  Singapur   0202  Productos cárnicos  2006         33.84           nan
# 2  Singapur   0203  Productos cárnicos  2006      17698.61         20.34
# 3  Singapur   0204  Productos cárnicos  2006         11.84           nan
# 4  Singapur   0205  Productos cárnicos  2006           nan           nan

# %% [markdown]
# Paises totales por tarics

# %%
df_vietnam.head()
# Out:
#       País Tarics         Descripción   Año Exportaciones Importaciones
# 0  Vietnam   0201  Productos cárnicos  2006         22.81           nan
# 1  Vietnam   0202  Productos cárnicos  2006           nan           nan
# 2  Vietnam   0203  Productos cárnicos  2006         29.32           nan
# 3  Vietnam   0204  Productos cárnicos  2006           nan           nan
# 4  Vietnam   0205  Productos cárnicos  2006           nan           nan

# %% [markdown]
# Lista de aranceles del caso particular del acuerdo entre la UE y Corea del Sur y dispersiones

# %%
aranceles.head()
# Out:
#    Aranceles pre Corea  Aranceles pre UE  Aranceles post Corea  \
# 0                 40.0                13                  15.0
# 1                 40.0                13                  15.0
# 2                 22.5                60                   7.5
# 3                 22.5                13                  10.0
# 4                 27.0                 5                  10.0
#
#    Aranceles post UE
# 0                  5
# 1                  5
# 2                  0
# 3                  0
# 4                  0

# %%
violin_pre(aranceles)

# %%
violin_post(aranceles)

# %% [markdown]
# Base de datos SQL

# %%
tiempo_trabajo = np.array([5, 15, 13, 7, 10, 2, 4, 2])
horitas(tiempo_trabajo)

# %%
grafico_t_columnas_num(df_paises,"paises")

# %%
grafico_t_columnas_num(df_corea1,"corea1")

# %%
grafico_t_columnas_num(df_japon1,"japon1")

# %%
grafico_t_columnas_num(df_canada1,"canada1")
